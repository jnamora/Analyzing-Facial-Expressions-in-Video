# %%
# import all the libraries, that we will need in this notebook
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import copy
import matplotlib
import math
import random
from scipy.stats import f_oneway
import seaborn as sns

# %% [markdown]
# # 2 Preparing the dataset

# %%
emotions_dict = {
    "01": "neutral",
    "02": "calm",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fearful",
    "07": "disgust",
    "08": "surprised"
}

def get_emotion_actor(f_name):
    # split the file name at the dashes
    f_name = f_name.split("-")
    # extract the information from each of the parts of the file name
    emotion = emotions_dict[f_name[2]]
    actor = int(f_name[6].split(".")[0])
    return emotion, actor

get_emotion_actor("03-01-01-01-01-01-01.wav")
# Out:
# ('neutral', 1)

# %% [markdown]
# #### 2.1 Getting the file names for each subject / emotion

# %%
files = os.listdir("data")

# create a dictionary to store the file names by subject
filenames = []
actors = []
emotions = []

# loop over all the files
for f in files:
    # extract the information from the file name
    emotion, actor = get_emotion_actor(f)
    # add the file name to the corresponding list in the dictionaries
    filenames.append(f)
    emotions.append(emotion)
    actors.append(actor)


# sort by actor and get the indexes to sort also the filenames and emotions
idx = np.argsort(actors)

# sort the lists
actors = np.array(actors)[idx]
emotions = np.array(emotions)[idx]
filenames = np.array(filenames)[idx]

# %% [markdown]
# #### 2.2 and 2.3 Loading the data

# %%
def load_data_from_file(f_name):
    """ function loads the data from a file and returns it as a numpy array
    :param f_name: file name
    :return: numpy array with the data """
    # load the data from the file to a pandas dataframe
    data = pd.read_csv("data/" + f_name)
    # only keep the columns x_0, ... x_67 and y_0, ... y_67
    keep_columns = [f"x_{i}" for i in range(68)] + [f"y_{i}" for i in range(68)]
    data = data[keep_columns]
    # convert to numpy array
    data = data.to_numpy()
    return data


def load_data_from_files(f_names):
    """ function loads the data from a list of files and returns it as a 3D numpy array
    of shape (n_samples, max_n_frames, n_features=136)
    :param f_names: list of file names
    :return: numpy array with the data """
    # prepare the lists to store the data
    data = []
    # loop over all the files
    for f_name in f_names:
        # load the data from the file and append it to the list
        data.append(load_data_from_file(f_name))
        # extract the emotion from the file name and append it to the list

    # find the maximum number of frames in all the data
    max_length = max([d.shape[0] for d in data])
    # pad the data with zeros
    padded_data = []
    for d in data:
        pad_length = max_length - d.shape[0]
        # pad the data with NaNs
        # check out the documentation at https://numpy.org/doc/stable/reference/generated/numpy.pad.html
        data_with_pad = np.pad(d, ((0, pad_length), (0, 0)), "constant", constant_values=np.nan)
        padded_data.append(data_with_pad)
    # stack the data together to get a 3D numpy array
    # check out https://numpy.org/doc/stable/reference/generated/numpy.stack.html
    stacked_data = np.stack(padded_data)
    return stacked_data

# %%
# run only the first time, to load the data from the files
all_data = load_data_from_files(filenames)

np.save("all_data.npy", all_data)
np.save("emotions.npy", emotions)
np.save("actors.npy", actors)

# %%
# load the data from the files
all_data = np.load("all_data.npy")
emotions = np.load("emotions.npy")
actors = np.load("actors.npy")

# %% [markdown]
# #### 2.4 and 2.5 Visualizing the data

# %%
def visualize_frame(frame, ax, x_lim=(0, 1280), y_lim=(0, 720), color="r"):
    """ function visualizes a single frame of the video on the given axis """
    ax.scatter(frame[:68], frame[68:], c=color, s=1, alpha=0.5)
    ax.set_xlim(x_lim)
    ax.set_ylim(y_lim)
    ax.set_aspect("equal")
    ax.invert_yaxis()

# test the visualization, by plotting the first frame of the first video for each emotion
_, axs = plt.subplots(4, 2, figsize=(8, 10))
axs = axs.flatten()

unique_emotions = np.unique(emotions)
for emotion, ax in zip(unique_emotions, axs):
    # get the index of the first video with the given emotion
    first_video_idx = np.where(emotions == emotion)[0][0]

    # plot the first frame of the first video
    visualize_frame(all_data[first_video_idx, 0, :], ax)
    ax.set_title(emotion)

plt.show()

# %%
def visualize_video(frames, ax, x_lim=(0, 1280), y_lim=(0, 720), color="r"):
    """ function visualizes a video on the given axis, by plotting all the frames """
    for frame in frames:
        visualize_frame(frame, ax, x_lim, y_lim, color)

# test the visualization, by plotting the first video for each emotion
_, axs = plt.subplots(4, 2, figsize=(8, 10))
axs = axs.flatten()

unique_emotions = np.unique(emotions)
for emotion, ax in zip(unique_emotions, axs):
    # get the index of the first video with the given emotion
    first_video_idx = np.where(emotions == emotion)[0][0]

    visualize_video(all_data[first_video_idx, :, :], ax)
    ax.set_title(emotion)

plt.show()

# %% [markdown]
# # 3 Outlier analysis and treatment
# #### 3.1 Normalizing the data

# %%
def normalize_frame(frame):
    """ function normalizes a single frame of the video """
    x_ref, y_ref = frame[27], frame[68+27]
    x_max = 1280
    y_max = 720
    x_norm = (frame[:68] - x_ref) / x_max
    y_norm = (frame[68:] - y_ref) / y_max
    frame_norm = np.concatenate((x_norm, y_norm), axis=0)
    return frame_norm

# %%
# normalize the data
all_data_normalized = np.apply_along_axis(normalize_frame, 2, all_data)
np.save("all_data_normalized.npy", all_data_normalized)

# reshape the data from (n_samples, max_n_frames, n_features=136)
# to (n_samples * max_n_frames, n_features=136), and remove the NaN frames after
all_data_normalized_2D = all_data_normalized.reshape(-1, 136)
emotions_2D = np.repeat(emotions, all_data_normalized_2D.shape[0] / emotions.shape[0])

# remove the NaN frames and the corresponding emotions
emotions_2D = emotions_2D[~np.isnan(all_data_normalized_2D).any(axis=1)]
all_data_normalized_2D = all_data_normalized_2D[~np.isnan(all_data_normalized_2D).any(axis=1)]

print("3D shape: ", all_data_normalized.shape, emotions.shape)
print("2D shape: ", all_data_normalized_2D.shape, emotions_2D.shape)

# save the normalized data to a file
np.save("all_data_normalized_2D.npy", all_data_normalized_2D)
np.save("emotions_2D.npy", emotions_2D)
# Out:
# 3D shape:  (2452, 191, 136) (2452,)
# 2D shape:  (299854, 136) (299854,)

# %% [markdown]
# #### 3.2 Outlier analysis

# %%
# create a dictionary with the values for chosen variable for each emotion
values_by_emotion = {}
chosen_variable = 54
for emotion in emotions_dict.values():
    emotion_data = all_data_normalized_2D[emotions_2D == emotion]
    values_by_emotion[emotion] = emotion_data[:, chosen_variable]

# create a boxplot for the chosen variable
plt.boxplot([values_by_emotion[emotion] for emotion in emotions_dict.values()],
            labels=emotions_dict.values(), flierprops={'marker': 'o', 'markerfacecolor': 'g',
            'markersize': 4})
plt.title(f"Values of variable {chosen_variable} for each emotion")
# Out:
# Text(0.5, 1.0, 'Values of variable 54 for each emotion')

# %% [markdown]
# #### 3.3 Density of outliers

# %%
# get the number of outliers for each emotion
def density_of_outliers_by_emotion(emotion):
    all_variables = all_data_normalized_2D[emotions_2D == emotion]
    q1 = np.quantile(all_variables, 0.25, axis=0)
    q3 = np.quantile(all_variables, 0.75, axis=0)
    inter_quartile_range = (q3 - q1).reshape(1, -1)
    outliers_above = np.sum(all_variables > q3 + 1.5 * inter_quartile_range, axis=0)
    outliers_below = np.sum(all_variables < q1 - 1.5 * inter_quartile_range, axis=0)
    # count non nan values
    return (outliers_above + outliers_below) / len(all_variables) * 100


print("Emotion    | Mean | Std  |")
print("-----------|------|------|")
for emotion in emotions_dict.values():
    outlier_density = density_of_outliers_by_emotion(emotion)
    # create a such print:
    print(f"{emotion:10} | {np.mean(outlier_density):.2f} | {np.std(outlier_density):.2f} |")
    plt.plot(outlier_density, label=emotion)
plt.title("Density of outliers by emotion and variable")
plt.legend()
# Out:
# Emotion    | Mean | Std  |
# -----------|------|------|
# neutral    | 1.20 | 1.70 |
# calm       | 2.28 | 1.41 |
# happy      | 1.87 | 1.11 |
# sad        | 1.34 | 0.97 |
# angry      | 2.08 | 0.98 |
# fearful    | 2.74 | 1.56 |
# disgust    | 2.62 | 1.94 |
# surprised  | 1.99 | 1.83 |

# %% [markdown]
# ##### Comment on the results
# We can observe that the emotions with the lowest mean of the density of outliers are neutral and sad, which intuitively makes sense, as these are the emotions where the face is most static. On the other side we see that fearful and disgust have more outliers.
#
# It also looks like that there are more outliers in the first half of the plot, where the x variables are plotted, compared to the second half, where the y variables are plotted.

# %% [markdown]
# #### 3.4 and 3.5 Z-score test for identifying outliers

# %%
def identify_outliers(samples, k=3):
    """ function identifies the outliers using the z-score test"""
    z_scores = np.abs(stats.zscore(samples))
    return np.where(z_scores < k)[0], np.where(z_scores >= k)[0]

# select a variable
chosen_variable = 54

for k in [3, 3.5, 4]:
    for emotion in emotions_dict.values():
        emotion_data = all_data_normalized_2D[emotions_2D == emotion]
        # take the data of one variable and identify the outliers
        var_data = emotion_data[:, chosen_variable]
        not_outliers_idx, outliers_ixd = identify_outliers(var_data, k=k)
        injected_outliers = var_data[outliers_ixd]
        not_outliers = var_data[not_outliers_idx]

        # plot the outliers with red and not outliers with black
        plt.scatter([emotion] * len(injected_outliers), injected_outliers, c="r", s=2)
        plt.scatter([emotion] * len(not_outliers), not_outliers, c="k", s=2)

    plt.title(f"k = {k}")
    plt.show()

# %% [markdown]
# ##### Compare the results in 3.2 and 3.5
# The outliers calculated in 3.2 and 3.5 are similar, but not the same, as we use two different methods. For some emotions, there is a lot less outliers, when using the z-score test, for example for the emotion "calm", there is already very little outliers using k=3, and for k=4 there don't appear to be any outliers.

# %% [markdown]
# #### 3.7 K-means clustering

# %%
def k_means(points, n):
    """ function implements the k-means algorithm as described in the slides """
    # randomly select the n starting centers as n of the points
    center_indices = random.sample(list(range(len(points))), n)
    centers = []
    n_points = points.shape[0]
    for ci in center_indices:
        centers.append(tuple(points[ci]))

    while True:
        # copy the centers (we need to compare them later for stopping condition)
        old_centers = copy.deepcopy(centers)
        # create n empty clusters
        clusters = [[] for _ in range(n)]

        # create a num_points x num_centers matrix with the distances between each point and each center
        distances = np.zeros((len(points), n))
        for i, center in enumerate(centers):
            center = np.array([center])
            # compute distance between one center and all points
            distances[:, i] = np.linalg.norm(points - np.repeat(center, n_points, axis=0), axis=1)

        # for each point, find the closest center and add the point to the cluster of the center
        for i, point in enumerate(points):
            min_idx = np.argmin(distances[i, :])
            clusters[min_idx].append(point)

        # calculate new centers, by taking the mean of the points in the cluster
        centers = []
        for cluster in clusters:
            mean = np.mean(cluster, axis=0)
            centers.append(tuple(mean))

        if set(centers) == set(old_centers):
            return clusters

# %% [markdown]
# #### 3.8 Determine the outliers using k-means clustering

# %%
k = 12
# don't use all the data, as it takes too long
k_means_clusters = k_means(all_data_normalized_2D[:10000, :], n=k)

# %%
# for each cluster measure the mean and std of distance from center to the points:
# consider all points that are far from the center to be outliers
outliers = []
for cluster in k_means_clusters:
    cluster = np.array(cluster)
    # calculate center:
    mean = np.mean(cluster, axis=0)
    # calculate the distances:
    distances = np.linalg.norm(cluster - np.repeat([mean], len(cluster), axis=0), axis=1)
    # calculate the mean and std of the distances:
    mean_dist = np.mean(distances)
    std_dist = np.std(distances)
    # calculate the outliers:
    outliers.append(cluster[np.where(distances > mean_dist + 3 * std_dist)[0]])

# %%
COLORS = list(matplotlib.colors.CSS4_COLORS.values())
random.shuffle(COLORS)

# plot the clusters in 2D with different colors
fig, ax = plt.subplots()
# plot points and outliers
for i, cluster in enumerate(k_means_clusters):
    cluster = np.array(cluster)
    ax.scatter(cluster[:, 0], cluster[:, 1], color=COLORS[i], alpha=0.2, zorder=1)
    ax.scatter(outliers[i][:, 0], outliers[i][:, 1], color="red", marker="x", zorder=2)

ax.axis("equal")
ax.invert_yaxis()
ax.set_title(f"k = {k}")
plt.show()

# %% [markdown]
# #### 3.9 Inject outliers

# %%
def inject_outliers(array, goal_density, k=3):
    """ function injects outliers into the array, until the goal density is reached """
    array = copy.deepcopy(array)
    non_outlier_idx, outliers_idx = identify_outliers(array, k=k)
    density = len(outliers_idx) / len(array) * 100

    if density < goal_density:
        density_diff = goal_density - density
        num_new_outliers = math.ceil(len(array) * density_diff / 100)
        mu = np.mean(array)
        sigma = np.std(array)

        # choose random indexes from the non outliers and replace them with outliers
        random_idx = np.random.choice(non_outlier_idx, size=num_new_outliers, replace=False)

        for idx in random_idx:
            s = random.choice([-1, 1])
            q = random.uniform(0, k * sigma)
            array[idx] = mu + s * k * sigma + s * q

    return array

# test the function:
variable_data = all_data_normalized_2D[:, 54].flatten()
variable_data = variable_data[~np.isnan(variable_data)]

plt.hist(variable_data, bins=100)
plt.show()

variable_data = inject_outliers(variable_data, goal_density=10, k=3)
plt.hist(variable_data, bins=100)
plt.show()

# %% [markdown]
# #### 3.10 Linear model

# %%
def linear_model(X, Y):
    # add a column of ones to X
    X = np.hstack((np.ones((X.shape[0], 1)), X))
    # do SVD decomposition of X
    U, S, Vt = np.linalg.svd(X, full_matrices=False)

    S_inv = np.diag([1 / s if s > 1e-14 else 0 for s in S])
    X_plus = Vt.T @ S_inv @ U.T
    beta = X_plus @ Y

    return beta

# plot a simple 2d linear regression test
X = np.random.rand(100, 1)
Y = 2 * X + 3 + np.random.randn(100, 1) * 0.1
beta = linear_model(X, Y)

plt.scatter(X, Y)
plt.plot(X, beta[0] + beta[1] * X, c="r")
plt.show()

# %% [markdown]
# #### 3.11 Linear model for y coordinate 57

# %%
x = all_data_normalized_2D[:1000, 57]
y = all_data_normalized_2D[:1000, 57 + 68]
y_injected = inject_outliers(y, 5)

injected_outliers = y != y_injected
injected_outliers_indices = np.where(injected_outliers == True)[0]
print(injected_outliers_indices)

for p in range(1, 4):

    for idx in injected_outliers_indices:
        X = np.array(x[idx-p-1:idx-1]).reshape(-1, 1)
        Y = np.array(y_injected[idx-p-1:idx-1]).reshape(-1, 1)
        beta = linear_model(X, Y)
        y_injected[idx] = beta[0] + beta[1] * x[idx]

    true_values = y[injected_outliers]
    predicted_values = y_injected[injected_outliers]

    errors = true_values - predicted_values
    plt.hist(errors, bins=100)
    plt.title(f"histogram of errors with window of length {p}")
    plt.show()
    plt.title(f"true values vs predicted values with window of length {p}")
    plt.plot(y, label="true values")
    plt.plot(y_injected, label="predicted values")
    plt.legend()
    plt.show()

    sum_of_squares_error = np.sum(np.power((true_values - predicted_values), 2))
    print(p, sum_of_squares_error)
# Out:
# [ 99 106 107 163 178 200 242 264 282 351 355 399 417 424 428 435 443 463
#  527 535 539 552 568 578 580 630 646 664 708 725 741 754 779 784 794 806
#  815 829 858 859 865 891 892 909 946 964]
# 1 0.001862089882459077
# 2 0.007027870861660892
# 3 0.008946274199327914

# %% [markdown]
# #### 3.11 Linear model for y coordinate 57

# %%
x = all_data_normalized_2D[:100, 57]
y56 = all_data_normalized_2D[:100, 56 + 68]
y = all_data_normalized_2D[:100, 57 + 68]
y58 = all_data_normalized_2D[:100, 58 + 68]
y_injected = inject_outliers(y, 5)

injected_outliers = y != y_injected
injected_outliers_indices = np.where(injected_outliers == True)[0]
print(injected_outliers_indices)

for p in range(2, 8, 2):
    for idx in injected_outliers_indices:
        X = np.vstack((x[idx-p//2:idx+p//2], y56[idx-p//2:idx+p//2], y58[idx-p//2:idx+p//2]))
        X = X.reshape(-1, 3)
        Y = np.array(y_injected[idx-p//2:idx+p//2]).reshape(-1, 1)
        beta = linear_model(X, Y)
        y_injected[idx] = beta[0] + beta[1] * x[idx]

    true_values = y[injected_outliers]
    predicted_values = y_injected[injected_outliers]

    errors = true_values - predicted_values
    plt.hist(errors, bins=100)
    plt.title(f"histogram of errors with window of length {p+1}")
    plt.show()
    plt.title(f"true values vs predicted values with window of length {p+1}")
    plt.plot(y, label="true values")
    plt.plot(y_injected, label="predicted values")
    plt.legend()
    plt.show()

    sum_of_squares_error = np.sum(np.power((true_values - predicted_values), 2))
    print(p, sum_of_squares_error)
# Out:
# [26 42 86 94 97]
# 2 0.0017319077313674685
# 4 0.00015415997888668827
# 6 0.0021606803473498424

# %% [markdown]
# # 4. Feature selection

# %% [markdown]
# Load the data from files and normalize it, but for each video separately

# %%
# load the data from the file
all_data_normalized = np.load("all_data_normalized.npy")
emotions = np.load("emotions.npy")
print(all_data_normalized.shape)
print(emotions.shape)
# Out:
# (2452, 191, 136)
# (2452,)

# %% [markdown]
# #### 4.1 EXTRACTING FEATURES

# %%
# helper functions (they all work on arrays also)
def calc_distance(x1, y1, x2, y2):
    """ calculates distance between points (x1, y1) and (x2, y2) """
    diff = np.vstack((x1 - x2, y1 - y2))
    return np.linalg.norm(diff, axis=0)

def calc_speed(x1, y1, x2, y2):
    """ calculates speed between points (x1, y1) and (x2, y2) """
    dist = calc_distance(x1, y1, x2, y2)
    return dist[:-1] - dist[1:]

def calc_triangle_area(x1, y1, x2, y2, x3, y3):
     """ calculates area of the triangle, defined by points (x1, y1), (x2, y2) and (x3, y3) """
     return abs(x1 * (y2 - y3) + x2 * (y3 - y1) + x3 * (y1 - y2)) / 2

def calc_angle(x1, y1, x2, y2):
    """ calculates the angle between horizontal line and line between points (x1, y1) and (x2, y2) """
    dx = x2 - x1
    dx[dx == 0] = 1e-10
    return np.arctan((y2 - y1) / dx)

# %% [markdown]
# ##### 4.1.1 Defining landmarks & calculating statistical features

# %%
# calculate the features for landmarks
landmarks = [8, 18, 20, 23, 25, 30, 31, 35, 36, 45, 48, 51, 54, 57]
features = {}

for xy in ["x", "y"]:
    for landmark in landmarks:
        feature_name = f"mean_landmark_{landmark}_{xy}"
        features[feature_name] = []
        variable = landmark if xy == "x" else landmark + 68

        # calculate the features for each video
        for video in range(len(all_data_normalized)):
            data = all_data_normalized[video, :, variable]
            data = data[~np.isnan(data)]
            mean = np.mean(data)

            features[feature_name].append(mean)

# %%
# calculate the features for average distance, std distance and average speed between landmarks
pairs_of_points = [[31, 39], [35, 42], [38, 40], [43, 47],  [41, 48], [48, 54],
                   [46, 54], [62, 66], [51, 57], [20, 38], [23, 43], [1, 31], [15, 35]]

for points in pairs_of_points:
    x1 = points[0]
    x2 = points[1]
    y1 = x1 + 68
    y2 = x2 + 68

    features[f"mean_distance_{x1}_{x2}"] = []
    features[ f"std_distance_{x1}_{x2}"] = []
    features[f"mean_speed_{x1}_{x2}"] = []

    for video in range(len(all_data_normalized)):
        data = [all_data_normalized[video, :, variable] for variable in [x1, y1, x2, y2]]
        # remove nan values
        data = [d[~np.isnan(d)] for d in data]

        # calculate the distance between the points
        distance = calc_distance(data[0], data[1], data[2], data[3])
        speed = calc_speed(data[0], data[1], data[2], data[3])
        # calculate the features
        features[f"mean_distance_{x1}_{x2}"].append(np.mean(distance))
        features[f"std_distance_{x1}_{x2}"].append(np.std(distance))
        features[f"mean_speed_{x1}_{x2}"].append(np.mean(speed))

# %% [markdown]
# ##### 4.1.2 Defining triangles & angles

# %%
triangles = [[18, 25, 30], [20, 23, 30], [48, 54, 30], [51, 57, 48], [51, 57, 54], [31, 35, 30],
             [36, 37, 41], [38, 39, 40], [37, 38, 40], [36, 37, 39]]

for points in triangles:
    x1 = points[0]
    x2 = points[1]
    x3 = points[2]
    y1 = x1 + 68
    y2 = x2 + 68
    y3 = x3 + 68

    features[f"triangle_area_{x1}_{x2}_{x3}"] = []

    for video in range(len(all_data_normalized)):
        data = [all_data_normalized[video, :, variable] for variable in [x1, y1, x2, y2, x3, y3]]
        # remove nan values
        data = [d[~np.isnan(d)] for d in data]
        triangle_area = calc_triangle_area(data[0], data[1], data[2], data[3], data[4], data[5])
        # calculate the features
        features[f"triangle_area_{x1}_{x2}_{x3}"].append(np.mean(triangle_area))

# %%
angles_vectors = [[18, 20], [23, 25], [48, 60], [54, 64], [51, 57]]

for points in angles_vectors:
    x1 = points[0]
    x2 = points[1]
    y1 = x1 + 68
    y2 = x2 + 68

    features[f"mean_angles_{x1}_{x2}"] = []
    features[f"std_angles_{x1}_{x2}"] = []

    for video in range(len(all_data_normalized)):
        data = [all_data_normalized[video, :, variable] for variable in [x1, y1, x2, y2]]
        # remove nan values
        data = [d[~np.isnan(d)] for d in data]

        # calculate the distance between the points
        angles = calc_angle(data[0], data[1], data[2], data[3])
        # calculate the features
        features[f"mean_angles_{x1}_{x2}"].append(np.mean(angles))
        features[f"std_angles_{x1}_{x2}"].append(np.std(angles))

# %% [markdown]
# #### 4.2 ANALYZE DISTRIBUTION AND STATISTICAL SIGNIFICANCE

# %%
# create a dataframe from the features
features_df = pd.DataFrame(features)
features_df["emotion"] = emotions
features_df.head()

# save the dataframe to a file
features_df.to_csv("features.csv", index=False)

# %%
features_df
# Out:
#       mean_landmark_8_x  mean_landmark_18_x  mean_landmark_20_x  \
# 0             -0.003456           -0.085521           -0.044221
# 1              0.011122           -0.092113           -0.048924
# 2              0.009244           -0.087215           -0.046462
# 3              0.007713           -0.086911           -0.045198
# 4              0.009234           -0.086242           -0.044286
# ...                 ...                 ...                 ...
# 2447           0.018905           -0.093735           -0.054921
# 2448           0.011339           -0.091889           -0.053331
# 2449           0.008116           -0.089657           -0.051534
# 2450           0.012673           -0.091950           -0.053270
# 2451           0.009547           -0.089097           -0.051756
#
#       mean_landmark_23_x  mean_landmark_25_x  mean_landmark_30_x  \
# 0               0.048064            0.089153           -0.005041
# 1               0.047271            0.088136            0.000811
# 2               0.045763            0.085337           -0.001297
# 3               0.045424            0.086832           -0.000645
# 4               0.043828            0.084145            0.001437
# ...                  ...                 ...                 ...
# 2447            0.049453            0.090743            0.001965
# 2448            0.049648            0.087976            0.001548
# 2449            0.049218            0.086765            0.000857
# 2450            0.049370            0.087998            0.001826
# 2451            0.046262            0.079163            0.001634
#
#       mean_landmark_31_x  mean_landmark_35_x  mean_landmark_36_x  \
# 0              -0.027016            0.022305           -0.073578
# 1              -0.021231            0.027907           -0.077270
# 2              -0.023110            0.026279           -0.073784
# 3              -0.025696            0.029262           -0.074626
# 4              -0.024389            0.029863           -0.075360
# ...                  ...                 ...                 ...
# 2447           -0.018800            0.030616           -0.078159
# 2448           -0.021494            0.028743           -0.079844
# 2449           -0.022000            0.027483           -0.078484
# 2450           -0.020708            0.028811           -0.079685
# 2451           -0.020824            0.027408           -0.082747
#
#       mean_landmark_45_x  ...  std_angles_18_20  mean_angles_23_25  \
# 0               0.079522  ...          0.068046           0.006467
# 1               0.081739  ...          0.072044          -0.045955
# 2               0.079382  ...          0.033884           0.026439
# 3               0.079431  ...          0.036969          -0.110721
# 4               0.077158  ...          0.055476          -0.143814
# ...                  ...  ...               ...                ...
# 2447            0.085070  ...          0.032916           0.033057
# 2448            0.082685  ...          0.023589          -0.065240
# 2449            0.080983  ...          0.033917          -0.054571
# 2450            0.082692  ...          0.017473          -0.084250
# 2451            0.084599  ...          0.063031           0.111854
#
#       std_angles_23_25  mean_angles_48_60  std_angles_48_60  \
# 0             0.093918           0.285030          0.057876
# 1             0.075534           0.127599          0.115902
# 2             0.049140          -0.058211          0.063574
# 3             0.035098           0.315180          0.148363
# 4             0.047990           0.264809          0.104810
# ...                ...                ...               ...
# 2447          0.049622           0.106891          0.140945
# 2448          0.018693           0.082590          0.118849
# 2449          0.041450           0.181171          0.137230
# 2450          0.013467           0.071458          0.065965
# 2451          0.061911          -0.009420          0.214687
#
#       mean_angles_54_64  std_angles_54_64  mean_angles_51_57  \
# 0             -0.326576          0.116554          -0.687332
# 1             -0.441969          0.130155           1.536333
# 2             -0.228725          0.062730           1.545105
# 3             -0.509570          0.076049           1.203158
# 4             -0.506248          0.064715           1.196721
# ...                 ...               ...                ...
# 2447          -0.538022          0.073748           1.521675
# 2448          -0.414566          0.084336           1.541371
# 2449          -0.449917          0.112215           1.330641
# 2450          -0.408082          0.048346           1.539963
# 2451          -0.323705          0.192943           1.280468
#
#       std_angles_51_57  emotion
# 0             1.388869  neutral
# 1             0.010092  fearful
# 2             0.009806  fearful
# 3             0.981291  disgust
# 4             0.981133  disgust
# ...                ...      ...
# 2447          0.012004  neutral
# 2448          0.008667  neutral
# 2449          0.787897     calm
# 2450          0.007019  neutral
# 2451          0.854141  fearful
#
# [2452 rows x 88 columns]

# %%
# load the dataframe from a file
features_df = pd.read_csv("features.csv")

mean_df = features_df.groupby("emotion").mean()
mean_df.head(8)
# Out:
#            mean_landmark_8_x  mean_landmark_18_x  mean_landmark_20_x  \
# emotion
# angry               0.001523           -0.094455           -0.049041
# calm                0.000308           -0.092875           -0.049517
# disgust            -0.000991           -0.090253           -0.046316
# fearful             0.003198           -0.092056           -0.048158
# happy               0.001093           -0.094868           -0.051381
# neutral             0.002375           -0.094033           -0.049935
# sad                 0.003843           -0.092483           -0.048264
# surprised           0.001782           -0.093447           -0.049584
#
#            mean_landmark_23_x  mean_landmark_25_x  mean_landmark_30_x  \
# emotion
# angry                0.048024            0.091752            0.000820
# calm                 0.049006            0.090914            0.000144
# disgust              0.046023            0.089019           -0.000347
# fearful              0.047684            0.090924            0.000567
# happy                0.049697            0.092328            0.000418
# neutral              0.048946            0.091445            0.000783
# sad                  0.046661            0.089497            0.001465
# surprised            0.048553            0.091178            0.000545
#
#            mean_landmark_31_x  mean_landmark_35_x  mean_landmark_36_x  \
# emotion
# angry               -0.026212            0.026765           -0.083708
# calm                -0.026563            0.026358           -0.080825
# disgust             -0.028104            0.026837           -0.080827
# fearful             -0.025222            0.027021           -0.081806
# happy               -0.028761            0.028607           -0.082483
# neutral             -0.024915            0.026297           -0.082138
# sad                 -0.025195            0.028074           -0.081611
# surprised           -0.025816            0.026815           -0.082300
#
#            mean_landmark_45_x  ...  mean_angles_18_20  std_angles_18_20  \
# emotion                        ...
# angry                0.081251  ...           0.017841          0.075728
# calm                 0.079000  ...          -0.226739          0.090367
# disgust              0.079524  ...          -0.013274          0.077565
# fearful              0.081623  ...          -0.142614          0.064904
# happy                0.080351  ...          -0.181828          0.090344
# neutral              0.080222  ...          -0.161391          0.042903
# sad                  0.080353  ...          -0.166343          0.080361
# surprised            0.080970  ...          -0.075967          0.071276
#
#            mean_angles_23_25  std_angles_23_25  mean_angles_48_60  \
# emotion
# angry              -0.024677          0.073496           0.023829
# calm                0.209149          0.091513           0.023980
# disgust             0.043552          0.081152           0.082133
# fearful             0.136688          0.066590          -0.005469
# happy               0.166560          0.087435           0.188080
# neutral             0.132032          0.039017          -0.034213
# sad                 0.126176          0.076830           0.079400
# surprised           0.072073          0.071464           0.040183
#
#            std_angles_48_60  mean_angles_54_64  std_angles_54_64  \
# emotion
# angry              0.147378          -0.168310          0.117903
# calm               0.130653          -0.134914          0.114072
# disgust            0.117590          -0.143966          0.097260
# fearful            0.109751          -0.149241          0.088779
# happy              0.140815          -0.303348          0.121186
# neutral            0.090705          -0.118628          0.069875
# sad                0.112258          -0.229747          0.094778
# surprised          0.113020          -0.183324          0.091862
#
#            mean_angles_51_57  std_angles_51_57
# emotion
# angry               0.253659          0.760276
# calm                0.057141          0.573925
# disgust             0.215456          0.781642
# fearful             0.580983          0.681168
# happy               0.178625          0.877709
# neutral             0.387146          0.568051
# sad                 0.311655          0.532615
# surprised           0.309507          0.739242
#
# [8 rows x 87 columns]

# %% [markdown]
# #### Kolmogorov-Smirnov test to check if the features are normally distributed

# %%
# do the kolmogorov-smirnov test for each feature and emotion
print("                           ", end="")
for emotion in features_df["emotion"].unique():
    print(f"{emotion[:6]:6} ", end="")

for feature in features_df.columns[:-1]:
    print(f"\n{feature:25}", end="")
    for emotion in features_df["emotion"].unique():
        data = features_df[features_df["emotion"] == emotion][feature]
        # standardize the data
        data = (data - np.mean(data)) / np.std(data)

        test = stats.kstest(data, "norm")
        p_value = test.pvalue

        print(f"{p_value > 0.05:7}", end="")
# Out:
#                            neutra fearfu disgus calm   surpri happy  sad    angry
# mean_landmark_8_x              1      0      1      1      1      1      1      0
# mean_landmark_18_x             1      0      1      1      1      1      0      1
# mean_landmark_20_x             1      0      1      1      1      1      0      1
# mean_landmark_23_x             1      1      1      1      1      1      1      1
# mean_landmark_25_x             1      1      1      1      1      0      1      1
# mean_landmark_30_x             1      1      1      1      0      1      1      1
# mean_landmark_31_x             1      1      0      1      1      0      1      1
# mean_landmark_35_x             1      1      1      1      1      1      1      1
# mean_landmark_36_x             0      0      1      1      1      1      0      0
# mean_landmark_45_x             1      1      1      1      1      0      1      1
# mean_landmark_48_x             1      1      1      1      1      1      0      1
# mean_landmark_51_x             1      1      0      1      1      0      0      1
# mean_landmark_54_x             1      1      1      0      1      1      1      1
# mean_landmark_57_x             1      0      0      1      1      0      1      1
# mean_landmark_8_y              1      0      0      1      1      1      0      0
# mean_landmark_18_y             1      1      1      1      1      1      1      0
# mean_landmark_20_y             1      1      0      1      1      1      1      0
# mean_landmark_23_y             1      0      1      1      1      0      1      1
# mean_landmark_25_y             1      0      1      1      1      1      1      1
# mean_landmark_30_y             1      0      1      0      1      1      1      1
# mean_landmark_31_y             1      0      1      0      1      0      0      0
# mean_landmark_35_y             1      0      1      0      1      0      0      0
# mean_landmark_36_y             1      1      1      1      1      1      1      1
# mean_landmark_45_y             1      1      1      1      1      1      1      1
# mean_landmark_48_y             1      0      1      0      1      0      1      1
# mean_landmark_51_y             0      0      1      0      0      0      0      0
# mean_landmark_54_y             1      0      1      1      1      0      0      0
# mean_landmark_57_y             1      0      1      0      1      1      1      1
# mean_distance_31_39            1      0      1      1      1      1      0      0
# std_distance_31_39             1      0      0      0      1      0      1      0
# mean_speed_31_39               1      1      1      1      1      1      0      0
# mean_distance_35_42            1      0      1      1      1      1      1      0
# std_distance_35_42             1      0      0      0      1      0      1      0
# mean_speed_35_42               1      1      1      1      1      1      1      0
# mean_distance_38_40            1      0      1      1      1      1      1      1
# std_distance_38_40             0      0      1      1      0      1      0      0
# mean_speed_38_40               0      0      1      0      0      0      0      0
# mean_distance_43_47            1      0      1      1      1      1      1      1
# std_distance_43_47             0      0      1      1      0      1      0      0
# mean_speed_43_47               0      0      1      0      0      0      0      0
# mean_distance_41_48            1      0      1      1      1      0      1      0
# std_distance_41_48             1      0      0      0      1      0      0      1
# mean_speed_41_48               0      1      0      0      1      1      0      0
# mean_distance_48_54            1      1      1      1      1      1      1      1
# std_distance_48_54             1      0      0      0      0      1      0      1
# mean_speed_48_54               0      0      1      0      1      1      1      0
# mean_distance_46_54            1      0      1      0      1      0      1      0
# std_distance_46_54             1      0      0      0      0      0      0      1
# mean_speed_46_54               0      1      1      1      1      1      0      1
# mean_distance_62_66            0      1      1      0      1      1      0      1
# std_distance_62_66             0      0      0      1      1      1      1      1
# mean_speed_62_66               0      0      0      0      1      0      0      0
# mean_distance_51_57            1      1      1      1      1      1      1      1
# std_distance_51_57             1      0      0      0      0      1      1      1
# mean_speed_51_57               0      0      1      0      1      1      1      0
# mean_distance_20_38            1      1      0      0      1      1      1      1
# std_distance_20_38             1      0      0      0      1      1      0      0
# mean_speed_20_38               0      1      1      0      0      0      0      0
# mean_distance_23_43            1      1      0      0      1      1      1      1
# std_distance_23_43             1      0      1      0      1      1      0      0
# mean_speed_23_43               0      1      1      0      0      0      0      0
# mean_distance_1_31             1      0      1      0      1      1      1      1
# std_distance_1_31              0      0      0      0      0      0      0      0
# mean_speed_1_31                1      1      0      0      0      0      0      0
# mean_distance_15_35            1      0      1      1      0      1      1      1
# std_distance_15_35             0      0      0      0      0      0      0      0
# mean_speed_15_35               0      0      0      0      0      0      0      0
# triangle_area_18_25_30         1      0      1      1      1      0      0      1
# triangle_area_20_23_30         1      0      1      1      1      0      0      0
# triangle_area_48_54_30         1      1      1      1      1      1      1      1
# triangle_area_51_57_48         1      1      0      0      1      1      1      1
# triangle_area_51_57_54         1      1      1      0      1      1      1      1
# triangle_area_31_35_30         1      0      1      1      1      1      0      1
# triangle_area_36_37_41         1      1      1      1      1      1      1      1
# triangle_area_38_39_40         1      0      1      1      1      1      1      1
# triangle_area_37_38_40         1      0      1      1      1      1      1      1
# triangle_area_36_37_39         1      0      1      1      1      1      1      0
# mean_angles_18_20              1      1      1      1      1      1      1      1
# std_angles_18_20               0      0      1      0      1      0      0      0
# mean_angles_23_25              1      1      1      1      1      1      1      1
# std_angles_23_25               0      0      1      0      1      0      0      0
# mean_angles_48_60              1      1      1      1      1      1      1      1
# std_angles_48_60               0      0      1      0      1      0      0      1
# mean_angles_54_64              0      0      1      1      1      1      1      1
# std_angles_54_64               0      0      0      0      0      0      0      0
# mean_angles_51_57              0      0      0      0      0      0      0      0
# std_angles_51_57               0      0      0      0      0      0      0      0

# %% [markdown]
# As not all features are normally distributed, we will apply ONE WAY ANOVA to understand whether the means of features are statistically different across the emotions.

# %%
# Iterate over each feature column
for feature_column in features_df.columns[:-1]:
    feature_groups = [features_df[features_df['emotion'] == emotion][feature_column].astype(float) for emotion in features_df['emotion'].unique()]

    # Perform ANOVA
    f_statistic, p_value = f_oneway(*feature_groups)

    # Display results for each feature
    print(f"\nANOVA for '{feature_column}':")
    print("F-statistic:", f_statistic)
    print("P-value:", p_value)

    if p_value < 0.05:
        print("The means are significantly different.")
    else:
        print("The means are not significantly different.")
# Out:
# ANOVA for 'mean_landmark_8_x':
# F-statistic: 2.6582408376883913
# P-value: 0.009697519221114411
# The means are significantly different.
#
# ANOVA for 'mean_landmark_18_x':
# F-statistic: 10.147742179140247
# P-value: 1.4149145764634831e-12
# The means are significantly different.
#
# ANOVA for 'mean_landmark_20_x':
# F-statistic: 25.980533716479822
# P-value: 1.6590500942745847e-34
# The means are significantly different.
#
# ANOVA for 'mean_landmark_23_x':
# F-statistic: 19.038866489184723
# P-value: 6.60332637890273e-25
# The means are significantly different.
#
# ANOVA for 'mean_landmark_25_x':
# F-statistic: 6.383038150475699
# P-value: 1.850412100280045e-07
# The means are significantly different.
#
# ANOVA for 'mean_landmark_30_x':
# F-statistic: 3.822898904737202
# P-value: 0.0003865038376122229
# The means are significantly different.
#
# ANOVA for 'mean_landmark_31_x':
# F-statistic: 15.268923130326215
# P-value: 1.1416269293256588e-19
# The means are significantly different.
#
# ANOVA for 'mean_landmark_35_x':
# F-statistic: 7.167829036199483
# P-value: 1.6412464497875634e-08
# The means are significantly different.
#
# ANOVA for 'mean_landmark_36_x':
# F-statistic: 7.009629403250446
# P-value: 2.6797788841499163e-08
# The means are significantly different.
#
# ANOVA for 'mean_landmark_45_x':
# F-statistic: 8.607084497511028
# P-value: 1.8312467893125716e-10
# The means are significantly different.
#
# ANOVA for 'mean_landmark_48_x':
# F-statistic: 29.630089897974834
# P-value: 1.6304533341073496e-39
# The means are significantly different.
#
# ANOVA for 'mean_landmark_51_x':
# F-statistic: 3.5359771544876466
# P-value: 0.00087426071986256
# The means are significantly different.
#
# ANOVA for 'mean_landmark_54_x':
# F-statistic: 27.594971761443478
# P-value: 1.0018805178952042e-36
# The means are significantly different.
#
# ANOVA for 'mean_landmark_57_x':
# F-statistic: 3.3428567882885445
# P-value: 0.0015035766877578632
# The means are significantly different.
#
# ANOVA for 'mean_landmark_8_y':
# F-statistic: 8.887022288256507
# P-value: 7.592492461981775e-11
# The means are significantly different.
#
# ANOVA for 'mean_landmark_18_y':
# F-statistic: 9.973843443799272
# P-value: 2.454457078241384e-12
# The means are significantly different.
#
# ANOVA for 'mean_landmark_20_y':
# F-statistic: 40.84324284211153
# P-value: 1.1047496532100268e-54
# The means are significantly different.
#
# ANOVA for 'mean_landmark_23_y':
# F-statistic: 45.25815662850001
# P-value: 1.4706571897237713e-60
# The means are significantly different.
#
# ANOVA for 'mean_landmark_25_y':
# F-statistic: 10.704361785801355
# P-value: 2.4203321832082586e-13
# The means are significantly different.
#
# ANOVA for 'mean_landmark_30_y':
# F-statistic: 45.668570444424105
# P-value: 4.208760938309049e-61
# The means are significantly different.
#
# ANOVA for 'mean_landmark_31_y':
# F-statistic: 39.73857039318057
# P-value: 3.328117515428773e-53
# The means are significantly different.
#
# ANOVA for 'mean_landmark_35_y':
# F-statistic: 31.455601067115147
# P-value: 5.245264619117192e-42
# The means are significantly different.
#
# ANOVA for 'mean_landmark_36_y':
# F-statistic: 50.38228760216333
# P-value: 2.6218160078851516e-67
# The means are significantly different.
#
# ANOVA for 'mean_landmark_45_y':
# F-statistic: 47.191640579734006
# P-value: 4.092533852228632e-63
# The means are significantly different.
#
# ANOVA for 'mean_landmark_48_y':
# F-statistic: 51.022653624987
# P-value: 3.806727626489602e-68
# The means are significantly different.
#
# ANOVA for 'mean_landmark_51_y':
# F-statistic: 31.541961368723705
# P-value: 4.0000303707436064e-42
# The means are significantly different.
#
# ANOVA for 'mean_landmark_54_y':
# F-statistic: 34.726001736662674
# P-value: 1.8886898370652278e-46
# The means are significantly different.
#
# ANOVA for 'mean_landmark_57_y':
# F-statistic: 29.1984408446975
# P-value: 6.351951536370841e-39
# The means are significantly different.
#
# ANOVA for 'mean_distance_31_39':
# F-statistic: 51.92219472998103
# P-value: 2.5429161149049927e-69
# The means are significantly different.
#
# ANOVA for 'std_distance_31_39':
# F-statistic: 65.70578076007628
# P-value: 4.901748989598254e-87
# The means are significantly different.
#
# ANOVA for 'mean_speed_31_39':
# F-statistic: 20.783857006887906
# P-value: 2.506845215969778e-27
# The means are significantly different.
#
# ANOVA for 'mean_distance_35_42':
# F-statistic: 71.87447424422614
# P-value: 8.668697384066807e-95
# The means are significantly different.
#
# ANOVA for 'std_distance_35_42':
# F-statistic: 63.62576815828971
# P-value: 2.131326093352228e-84
# The means are significantly different.
#
# ANOVA for 'mean_speed_35_42':
# F-statistic: 22.92747661762174
# P-value: 2.7014830279973477e-30
# The means are significantly different.
#
# ANOVA for 'mean_distance_38_40':
# F-statistic: 194.84884638055803
# P-value: 5.503163865418012e-230
# The means are significantly different.
#
# ANOVA for 'std_distance_38_40':
# F-statistic: 20.763890269188124
# P-value: 2.671792039569345e-27
# The means are significantly different.
#
# ANOVA for 'mean_speed_38_40':
# F-statistic: 21.241734904086016
# P-value: 5.816229768455622e-28
# The means are significantly different.
#
# ANOVA for 'mean_distance_43_47':
# F-statistic: 189.33754269278202
# P-value: 1.3326182240432728e-224
# The means are significantly different.
#
# ANOVA for 'std_distance_43_47':
# F-statistic: 19.800875539852814
# P-value: 5.784269915586951e-26
# The means are significantly different.
#
# ANOVA for 'mean_speed_43_47':
# F-statistic: 22.277375962410694
# P-value: 2.1417000704504586e-29
# The means are significantly different.
#
# ANOVA for 'mean_distance_41_48':
# F-statistic: 67.81836824090578
# P-value: 1.0551492888753637e-89
# The means are significantly different.
#
# ANOVA for 'std_distance_41_48':
# F-statistic: 69.05934364642269
# P-value: 2.9008568444131677e-91
# The means are significantly different.
#
# ANOVA for 'mean_speed_41_48':
# F-statistic: 40.9891885447878
# P-value: 7.04907276929268e-55
# The means are significantly different.
#
# ANOVA for 'mean_distance_48_54':
# F-statistic: 187.442627244424
# P-value: 9.73837214187316e-223
# The means are significantly different.
#
# ANOVA for 'std_distance_48_54':
# F-statistic: 108.83786028421689
# P-value: 4.314501099286613e-139
# The means are significantly different.
#
# ANOVA for 'mean_speed_48_54':
# F-statistic: 60.552464429524
# P-value: 1.7761224107634255e-80
# The means are significantly different.
#
# ANOVA for 'mean_distance_46_54':
# F-statistic: 85.03620946324602
# P-value: 5.6186525763130016e-111
# The means are significantly different.
#
# ANOVA for 'std_distance_46_54':
# F-statistic: 75.2608232672303
# P-value: 5.339551938219053e-99
# The means are significantly different.
#
# ANOVA for 'mean_speed_46_54':
# F-statistic: 44.8640277778871
# P-value: 4.8951682651937706e-60
# The means are significantly different.
#
# ANOVA for 'mean_distance_62_66':
# F-statistic: 155.02541483949
# P-value: 8.352425648148055e-190
# The means are significantly different.
#
# ANOVA for 'std_distance_62_66':
# F-statistic: 126.28951977109126
# P-value: 8.094941980046518e-159
# The means are significantly different.
#
# ANOVA for 'mean_speed_62_66':
# F-statistic: 50.66671560085006
# P-value: 1.1123015564032245e-67
# The means are significantly different.
#
# ANOVA for 'mean_distance_51_57':
# F-statistic: 64.40284574212646
# P-value: 2.1956263825080475e-85
# The means are significantly different.
#
# ANOVA for 'std_distance_51_57':
# F-statistic: 128.88046774371068
# P-value: 1.0964384873541656e-161
# The means are significantly different.
#
# ANOVA for 'mean_speed_51_57':
# F-statistic: 37.55834522118005
# P-value: 2.826347640726066e-50
# The means are significantly different.
#
# ANOVA for 'mean_distance_20_38':
# F-statistic: 115.88482480672658
# P-value: 3.823520678044279e-147
# The means are significantly different.
#
# ANOVA for 'std_distance_20_38':
# F-statistic: 47.22645103258976
# P-value: 3.681985753764079e-63
# The means are significantly different.
#
# ANOVA for 'mean_speed_20_38':
# F-statistic: 19.371771874439958
# P-value: 2.2786507167342628e-25
# The means are significantly different.
#
# ANOVA for 'mean_distance_23_43':
# F-statistic: 120.1019748151732
# P-value: 6.611361870025707e-152
# The means are significantly different.
#
# ANOVA for 'std_distance_23_43':
# F-statistic: 50.19540438344968
# P-value: 4.606829220033455e-67
# The means are significantly different.
#
# ANOVA for 'mean_speed_23_43':
# F-statistic: 17.711406323790367
# P-value: 4.606176594611351e-23
# The means are significantly different.
#
# ANOVA for 'mean_distance_1_31':
# F-statistic: 64.06537760237464
# P-value: 5.888700982404921e-85
# The means are significantly different.
#
# ANOVA for 'std_distance_1_31':
# F-statistic: 31.75999523385893
# P-value: 2.0182826252742212e-42
# The means are significantly different.
#
# ANOVA for 'mean_speed_1_31':
# F-statistic: 8.52969867634103
# P-value: 2.3351683408122175e-10
# The means are significantly different.
#
# ANOVA for 'mean_distance_15_35':
# F-statistic: 78.2484740753986
# P-value: 1.0941892045939094e-102
# The means are significantly different.
#
# ANOVA for 'std_distance_15_35':
# F-statistic: 31.950314326505286
# P-value: 1.1111295227782257e-42
# The means are significantly different.
#
# ANOVA for 'mean_speed_15_35':
# F-statistic: 6.41598065516554
# P-value: 1.6723647555571521e-07
# The means are significantly different.
#
# ANOVA for 'triangle_area_18_25_30':
# F-statistic: 23.81396705852039
# P-value: 1.609706401820032e-31
# The means are significantly different.
#
# ANOVA for 'triangle_area_20_23_30':
# F-statistic: 18.394836382561802
# P-value: 5.1762029309219784e-24
# The means are significantly different.
#
# ANOVA for 'triangle_area_48_54_30':
# F-statistic: 32.932729707665345
# P-value: 5.119357057456526e-44
# The means are significantly different.
#
# ANOVA for 'triangle_area_51_57_48':
# F-statistic: 99.55462499682203
# P-value: 2.6826564025137506e-128
# The means are significantly different.
#
# ANOVA for 'triangle_area_51_57_54':
# F-statistic: 118.8239903391546
# P-value: 1.8155785762624514e-150
# The means are significantly different.
#
# ANOVA for 'triangle_area_31_35_30':
# F-statistic: 59.40620353768092
# P-value: 5.2333422120222335e-79
# The means are significantly different.
#
# ANOVA for 'triangle_area_36_37_41':
# F-statistic: 167.17305977280446
# P-value: 2.1990899940471217e-202
# The means are significantly different.
#
# ANOVA for 'triangle_area_38_39_40':
# F-statistic: 154.15236759291875
# P-value: 6.876624545440246e-189
# The means are significantly different.
#
# ANOVA for 'triangle_area_37_38_40':
# F-statistic: 183.14376839326192
# P-value: 1.7416518146107973e-218
# The means are significantly different.
#
# ANOVA for 'triangle_area_36_37_39':
# F-statistic: 153.16262329456882
# P-value: 7.537226933011139e-188
# The means are significantly different.
#
# ANOVA for 'mean_angles_18_20':
# F-statistic: 95.21036665252473
# P-value: 3.582124600991635e-123
# The means are significantly different.
#
# ANOVA for 'std_angles_18_20':
# F-statistic: 24.29213488398647
# P-value: 3.5212608516851065e-32
# The means are significantly different.
#
# ANOVA for 'mean_angles_23_25':
# F-statistic: 61.569363590435366
# P-value: 8.895043330093868e-82
# The means are significantly different.
#
# ANOVA for 'std_angles_23_25':
# F-statistic: 26.473906523650225
# P-value: 3.4760869970108206e-35
# The means are significantly different.
#
# ANOVA for 'mean_angles_48_60':
# F-statistic: 40.82493927881815
# P-value: 1.1688003708245994e-54
# The means are significantly different.
#
# ANOVA for 'std_angles_48_60':
# F-statistic: 34.21594408561393
# P-value: 9.27487297648278e-46
# The means are significantly different.
#
# ANOVA for 'mean_angles_54_64':
# F-statistic: 28.401106336214465
# P-value: 7.853357647947993e-38
# The means are significantly different.
#
# ANOVA for 'std_angles_54_64':
# F-statistic: 37.65841163145758
# P-value: 2.0725182978371926e-50
# The means are significantly different.
#
# ANOVA for 'mean_angles_51_57':
# F-statistic: 6.056033508614244
# P-value: 5.037262178639621e-07
# The means are significantly different.
#
# ANOVA for 'std_angles_51_57':
# F-statistic: 13.961539117970538
# P-value: 7.474408803741176e-18
# The means are significantly different.

# %% [markdown]
# #### 4.3 PCA

# %%
def PCA(features):
    """ Perform PCA on the features """
    # normalize the features
    P = (features - np.mean(features, axis=0)) / np.std(features, axis=0)
    PtP = np.dot(P.T, P)

    U, S, V = np.linalg.svd(PtP)

    print("num feat | explainability | cumulative")
    for i in range(min(30, len(S))):
        print(f"{i+1:9} | {S[i]/np.sum(S):14.2f} | {np.sum(S[:i+1])/np.sum(S):10.2f}")

    # calculate the principal components
    principal_components = np.dot(P, U)
    print(f"PCs shape: {principal_components.shape}")

    # scatter the first two principal components and color them by emotion
    sns.scatterplot(x=principal_components[:, 0], y=principal_components[:, 1], hue=emotions)
    plt.xlabel("First principal component")
    plt.ylabel("Second principal component")
    plt.gca().set_aspect('equal', 'datalim')

    return U, S, V, principal_components

# %%
# perform PCA on the features
features_np = features_df.drop("emotion", axis=1).values
U, S, V, PC = PCA(features_np)
# Out:
# num feat | explainability | cumulative
#         1 |           0.18 |       0.18
#         2 |           0.15 |       0.33
#         3 |           0.10 |       0.43
#         4 |           0.09 |       0.52
#         5 |           0.07 |       0.59
#         6 |           0.06 |       0.65
#         7 |           0.05 |       0.70
#         8 |           0.03 |       0.73
#         9 |           0.03 |       0.76
#        10 |           0.03 |       0.79
#        11 |           0.02 |       0.81
#        12 |           0.02 |       0.83
#        13 |           0.02 |       0.85
#        14 |           0.02 |       0.87
#        15 |           0.01 |       0.88
#        16 |           0.01 |       0.89
#        17 |           0.01 |       0.90
#        18 |           0.01 |       0.91
#        19 |           0.01 |       0.92
#        20 |           0.01 |       0.93
#        21 |           0.01 |       0.94
#        22 |           0.01 |       0.95
#        23 |           0.01 |       0.95
#        24 |           0.01 |       0.96
#        25 |           0.01 |       0.96
#        26 |           0.00 |       0.97
#        27 |           0.00 |       0.97
#        28 |           0.00 |       0.97
#        29 |           0.00 |       0.98
#        30 |           0.00 |       0.98
# PCs shape: (2452, 87)

# %% [markdown]
# By visualizing the graph, we can observe that the features exhibit significant dispersion, indicating a wide range of values across the dataset. This dispersion suggests that the features do not follow a specific pattern or structure. Moreover, the data seem to assume some sphericity, implying that the distribution of points in the space is relatively uniform.
#
# It's challenging to identify distinct clusters in the visualization, suggesting that the emotions may not be clearly separated in the space defined by the two main components. This lack of clear separation could imply that the selected features may not strongly contribute to the discrimination of emotions, and additional exploration or feature engineering may be necessary to enhance the model's ability to distinguish between different emotional states.
# At last, we have to use 9 features to explain 75% of our the dataset.

# %% [markdown]
# #### Compression for a video of choice

# %%
video = 0
video_features = features_np[video, :]

video_features_pc = np.dot(video_features, U)
video_features_pc[:9]
# Out:
# array([ 0.6027341 ,  0.04076075, -0.37020775,  0.12962129, -0.20079585,
#        -0.10668349,  0.13698977,  0.1553296 , -0.05539402])

# %% [markdown]
# #### 4.5 Fisher Score

# %%
# Fisher score
# https://arxiv.org/ftp/arxiv/papers/1202/1202.3725.pdf

def fisher_score(features_df):
    """ Calculate the fisher score for each feature """
    feat = features_df.columns[:-1]

    mu = features_df.groupby("emotion").mean()
    mu_all = features_df[feat].mean()
    sigma_all = features_df[feat].std()
    N = features_df.groupby("emotion").count().iloc[:, 0]
    fisher_scores = {}

    for f in feat:
        mu_f = mu[f]
        mu_all_f = mu_all[f]
        sigma_all_f = sigma_all[f]

        fisher_scores[f] = (N * (mu_f - mu_all_f) ** 2).sum() / max((sigma_all_f ** 2), 1e-14)

    return fisher_scores


scores = fisher_score(features_df.copy())

# %% [markdown]
# #### Remove correlated features

# %%
def remove_correlated_features(df, scores):
    """ Remove features with high correlation """
    # sort the scores
    sorted_scores = {k: v for k, v in sorted(scores.items(), key=lambda item: item[1], reverse=True)}
    removed_features = []

    for i, feature in enumerate(sorted_scores):
        if feature in removed_features:
            continue
        for other_feature in list(sorted_scores)[i+1:]:
            # print(f"{feature} - {other_feature}")
            corr = np.corrcoef(df[feature], df[other_feature])[0, 1]
            if abs(corr) > 0.9:
                removed_features.append(other_feature)

    # remove the features with high correlation
    for feature in removed_features:
        sorted_scores.pop(feature)

    return sorted_scores

sorted_scores = remove_correlated_features(features_df, scores)
top_10_fischer = []

for i, feature in enumerate(sorted_scores):
    if i == 10:
        break
    top_10_fischer.append(feature)
    print(f"{feature:22} | {sorted_scores[feature]:.2f}")
# Out:
# mean_distance_38_40    | 877.91
# mean_distance_48_54    | 856.20
# mean_distance_62_66    | 753.65
# std_distance_51_57     | 660.82
# mean_distance_23_43    | 627.33
# triangle_area_51_57_54 | 622.35
# std_distance_48_54     | 582.47
# triangle_area_51_57_48 | 543.81
# mean_angles_18_20      | 525.17
# mean_distance_46_54    | 480.04

# %% [markdown]
# After using the Fisher score, and removing highly correlated features, we should use the 10 features above.
# We emphasize that these results align with the scientific literature, underscoring their robustness. In a 2021 study, Cai, Li, and Lu delved into various feature selection methods for emotion recognition, highlighting the importance of specific facial features—especially those related to the mouth and eyebrows—in achieving accurate recognition.
# A couple of limitations are the lack of features in the nose, which might make it harder to identify emotions such as disgust. Some lack of symmetry in the eyebrows and eyes may pose challenges in capturing certain twitches expressions for some individuals.

# %%
from adjustText import adjust_text

def plot_landmarks(frame, landmarks):
    """ Plot the landmarks over the frame """
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.scatter(frame[:68], frame[68:], c="b", s=4, alpha=1)
    texts = []
    ax.set_facecolor((1.0, 1.0, 1.0))

    # plot over the landmarks with red
    for landmark in landmarks:
        l = landmark.split("_")
        if l[1] == "landmark":
            ax.scatter(frame[int(l[2])], frame[int(l[2]) + 68], c="r", s=4, alpha=1)
            texts.append(ax.annotate(landmark, (frame[int(l[2])], frame[int(l[2]) + 68]),
                        fontsize=8))
        elif l[1] in ["distance", "angles"]:
            ax.plot([frame[int(l[2])], frame[int(l[3])]],
                    [frame[int(l[2]) + 68], frame[int(l[3]) + 68]], c="r", alpha=1)
            texts.append(ax.annotate(landmark, ((frame[int(l[2])] + frame[int(l[3])])/2,
                                   (frame[int(l[2]) + 68] + frame[int(l[3]) + 68])/2),
                        fontsize=8))

    adjust_text(texts, only_move={'points':'y', 'texts':'y'},
                arrowprops=dict(arrowstyle="->", color='g', lw=0.5))
    ax.set_aspect("equal")
    ax.invert_yaxis()
    plt.show()

# %%
videos = np.load("all_data.npy")
frame = videos[0][0]
plot_landmarks(frame, top_10_fischer)

# %% [markdown]
# #### ReliefF

# %%
# implement ReliefF
# https://en.wikipedia.org/wiki/Relief_(feature_selection)

def ReliefF(features_df):
    """ Calculate the ReliefF score for each feature """
    X = features_df.drop("emotion", axis=1).values
    y = features_df["emotion"].values

    # scale each feature to [0,1] range
    X = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))

    num_instances, num_feat = X.shape

    dist = np.zeros((num_instances, num_instances))

    for i in range(num_instances):
        dist[i, :] = np.linalg.norm(X - X[i, :], axis=1)

    # calculate the nearest hit and nearest miss for each sample
    weights = np.zeros((num_feat,))
    for idx in range(num_instances):
        label = y[idx]

        # find the nearest hit and nearest miss
        hit_distances = dist[idx, :].copy()
        hit_distances[y != label] = np.inf
        hit_distances[idx] = np.inf
        miss_distances = dist[idx, :].copy()
        miss_distances[y == label] = np.inf
        nearest_hit = np.argsort(hit_distances)[:3]
        nearest_miss = np.argsort(miss_distances)[:3]

        # print("hit", idx, nearest_hit, nearest_miss)
        # print("nearest_miss", nearest_miss1, nearest_miss)

        # calculate the weight for each feature
        weights += (X[idx, :] - np.mean(X[nearest_miss, :], axis=0)) ** 2 - (
                    X[idx, :] - np.mean(X[nearest_hit, :], axis=0)) ** 2

    return weights / num_instances


weights = ReliefF(features_df)
weights = {k: v for k, v in zip(features_df.columns[:-1], weights)}

# %%
# sort the weights
sorted_weights = {k: v for k, v in sorted(weights.items(), key=lambda item: item[1], reverse=True)}

top_10_relieff = []
for i, feature in enumerate(sorted_weights):
    if i == 10:
        break
    top_10_relieff.append(feature)
    print(f"{feature:22} | {sorted_weights[feature]:.6f}")
# Out:
# mean_distance_48_54    | 0.008677
# mean_distance_62_66    | 0.007225
# std_distance_48_54     | 0.007014
# std_distance_51_57     | 0.006600
# mean_distance_23_43    | 0.005740
# mean_distance_20_38    | 0.005631
# std_distance_62_66     | 0.005432
# triangle_area_51_57_54 | 0.005170
# mean_angles_23_25      | 0.004232
# mean_distance_15_35    | 0.003979

# %% [markdown]
# The advantages of this approach seem to lie in the diversification of features between the eyes, eyebrows, and mouth. In a sense, it could be more sensitive in capturing a broader range of emotions. However, there appears to be an overemphasis on the nose in these results, potentially beneficial for capturing the disgust emotion. Nevertheless, the lack of features in the mouth raises concerns about overall reliability. Striking a more balanced feature distribution could further enhance the robustness of our approach.

# %%
plot_landmarks(frame, top_10_relieff)

# %%
# pick the top 10 features into a df
top_10_fischer_df = features_df[top_10_fischer]
top_10_relieff_df = features_df[top_10_relieff]

# %%
top_10_relieff_df.loc[:, "emotion"] = emotions
top_10_fischer_df.loc[:, "emotion"] = emotions

top_10_relieff_df.loc[:, "actor"] = actors
top_10_fischer_df.loc[:, "actor"] = actors

# save the data
top_10_relieff_df.to_csv("top_10_relieff.csv", index=False)
top_10_fischer_df.to_csv("top_10_fischer.csv", index=False)

# %% [markdown]
# Authors:
#
# Nace Sever	uc2023158749@student.uc.pt
#
# José Pedro Namora Pereira Dias	uc2023164985@student.uc.pt
